# %%
# import modules
import numpy as np
import matplotlib.pyplot as plt


from src import utils, painting_tools
from pathlib import Path
import json
import os

# %% [markdown]
# # 1. paint the energy consumption

# %% [markdown]
# 1.1 paint the energy consumption of inferece task

# %%
# 从results.json文件读取数据
with open("./results/energy_results.json", "r") as file:
    data = json.load(file)

# %%
# %matplotlib inline
# 调用函数并返回图形列表
fig_list = painting_tools.plot_energy_consumption(data)

# 显示所有生成的图形
for fig in fig_list:
    fig.show()

# 保存图像为 EPS格式
if 1: 
    for i, fig in enumerate(fig_list):
        fig.savefig(f"./results/energy_consumption/energy_consumption_{i + 1}.eps", format="eps", bbox_inches="tight")
# Out:
# /tmp/ipykernel_224490/1799382472.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# 1.2 paint the energy consumption of retraining

# %%
data_dict = {
    'data': [ 1.2,5.7, 400.78],
    'colors': ['#FA7D0F','#CC2628', '#1A689C'],
    'labels': ['DNN-based DTOO [10]', 'TaCo (Ours)', 'BO-based PTC [9]'],
    'xlabel': 'Time cost for retraining 100 episodes (s)'
}

# 调用函数
fig = painting_tools.create_broken_bar_chart(data_dict)
fig.show()


# 保存图像为 EPS 和 PDF 格式

if 1: 
    fig.savefig(f"./results/Time cost_retraining_100_episodes_taco_DNN_BO.eps", format="eps", bbox_inches="tight")
    # fig.savefig(f"figure_{i + 1}.pdf", format="pdf", bbox_inches="tight")
    # plt.show(fig)  # 显示图形
# Out:
# /mnt/g/我的云端硬盘/Research_Staff/code/code_taco/src/painting_tools.py:144: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout()
# /tmp/ipykernel_224490/612197000.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# # 2. Draw the latency

# %% [markdown]
# 2.1 Draw latency performance of TaCo, DTOO and PTC

# %%
# 从results.json文件读取数据
with open("./results/TaCo_impl_results.json", "r") as file:
    latencies_data_taco = json.load(file)

with open("./results/DNN_impl_result.json", "r") as file:
    latencies_data_dnn = json.load(file)    

with open("./results/BO_impl_result.json", "r") as file:
    latencies_data_bo = json.load(file)    

latencies_data_taco = latencies_data_taco["latencies"][:100]
latencies_data_dnn = latencies_data_dnn["latencies"]
latencies_data_bo = latencies_data_bo["latencies"]
print(len(latencies_data_taco), len(latencies_data_dnn), len(latencies_data_bo))



fig_comparision = painting_tools.plot_latency_comparison(latencies_data_taco, latencies_data_dnn, latencies_data_bo)
fig_comparision.show()

# 保存图像为 EPS 和 PDF 格式
if 1: 
    fig_comparision.savefig(f"./results/latency_comparision_taco_DNN_BO.eps", format="eps", bbox_inches="tight")
# Out:
# /tmp/ipykernel_224490/2247834804.py:19: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig_comparision.show()
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 100 100 100
